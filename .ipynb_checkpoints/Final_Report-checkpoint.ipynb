# %% [markdown]
# ### CS/ECE/ISyE 524 &mdash; Introduction to Optimization &mdash; Spring 2026 ###
#
# # Project title goes here #
#
# #### Student 1 (email address), Student 2 (email address), Student 3 (email address)
#
# ### Table of Contents
#
# 1. [Introduction](#1.-Introduction)
# 1. [Mathematical Model](#2.-Mathematical-model)
# 1. [Implementation and Solution](#3.-Implementation)
# 1. [Discussion of Results](#4.-Results-discussion)
# 1. [Optional Subsection](#4.A.-Feel-free-to-add-subsections)
# 1. [Conclusion](#5.-Conclusion)

# %% [markdown]
# ## 1. Introduction ##
#
# Every year, the best team in NCAA Men's College Basketball is decided using a 68 team tournament referred to as March Madness. Every year millions of sports fans compete to create the most accurate prediction of how the tournament bracket plays out.
#
# The first few sentences should give a quick overview of the entire project. Then, elaborate with a description of the problem that will be solved, a brief history (with [citations](https://en.wikipedia.org/wiki/Citation)) of how the problem came about, why it's important/interesting, and any other interesting facts you'd like to talk about. You should address and explain where the problem data is coming from (research? the internet? synthetically generated?) Also give an outline of the rest of the report.
#
# This section **should be accessible to a general audience** (don't assume your reader has taken the class!). Feel free to include images if you think it'll be helpful:
#
# ![fixit flowchart][flow]
#
# For more help on using Markdown, see [this reference](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).
#
# [flow]: https://s-media-cache-ak0.pinimg.com/736x/f5/75/c5/f575c53b93724808c6f0211890a54900.jpg

# %% [markdown]
# ## 2. Mathematical model ##
#
# A discussion of the modeling assumptions made in the problem (e.g. is it from physics? economics? something else?). Explain the decision variables, the constraints, and the objective function. Finally, show the optimization problem written in standard form. If converting the problem to standard form would create a difficult-to-read model, it is okay to leave it in its simplest original form. Equations should be formatted in $\\LaTeX$ within the IJulia notebook. For this section you may **assume the reader is familiar with the material covered in class**.
#
# Here is an example of an equation:
#
# $$\begin{bmatrix}
#       1 & 2 \\
#        3 & 4
#     \end{bmatrix}
#     \begin{bmatrix} x \\ y \end{bmatrix} =
#     \begin{bmatrix} 5 \\ 6 \end{bmatrix}$$
#
# And here is an example of an optimization problem in easy-to-read form:
# $$\begin{aligned}
#   \underset{x \in \mathbb{R^n}}{\text{maximize}}\qquad& f_0(x) \\
#     \text{subject to:}\qquad& f_i(x) \le 0 && i=1,\dots,m\\
#     & h_j(x) = 0 && j=1,\dots,r
#     \end{aligned}$$

# %% [markdown]
# ## 3. Implementation \& Solutions ##
#
# Here, you should code up your model in Julia + JuMP and solve it. Your code should be clean, easy to read, well annotated and commented, and it should compile! You are not allowed to use other programming languages or DCP packages such as `convex.jl`. I suggest having multiple code blocks separated by text blocks that explain the various parts of your solution. You may want to solve several versions of your problem with different models/assumptions. Suppress any code output that you don't explain in the body of the report.
#
# It's fine to call external packages such as `Gurobi`, but try to minimize the use of exotic libraries.
#
# To begin, we will make a simplified model of the 64-team bracket. Let's first consider the case of the Final Four, where there are only four teams remaining and hence three games. For the 2026 tournament, the Final Four was comprised of UConn, Michigan, Arizona, and Illinois.
#
# ![final_four_bracket][ff_bracket]
#
# The criteria for who wins in a head to head will, for this example, be a teams free-throw percentage. This is not a good predictor of success in an actual bracket, but is a metric that is simple enough to use for this example. Of these teams, Illinois shot 78.04%, Michigan shot 74.75%, UConn shot 72.40%, and Arizona shot 73.42%. This data is pulled from [the NCAA website](https://www.ncaa.com/stats/basketball-men/d1/current/team/150).
#
# [ff_bracket]: https://github.com/tylerwhite26/ISYE524_Final/blob/1be3e9a55df8de1d33620082dfe5ad395a86fc5a/ISYE524_Final_Four_Diagram.drawio.png

# %%
using JuMP, HiGHS

teams = ["Illinois", "Michigan", "UConn", "Arizona"] # team names
percentages = [78.04, 74.75, 72.40, 73.42] # associated ft percentage


ff = Model(HiGHS.Optimizer) # final four bracket model

# let the demand of each game decision node be 1. Supply of the teams is infinite, for this case only need at most 2.
# the amount of flow out of each team's node will determine how far they go in the bracket
team_nodes = [:UConn, :Illinois, :Arizona, :Michigan]
interior_nodes = [:UI, :AM, :CHAMP]
nodes = vcat(team_nodes, interior_nodes)
interior_demands = Dict(t => 1 for t in interior_nodes)

# make the arcs between nodes
arcs = [(:UConn, :UI), (:Illinois, :UI), (:UI, :CHAMP), (:Arizona, :AM), (:Michigan, :AM), (:AM, :CHAMP)]

# map team names to ft percentage
ftp = Dict(
    :UConn => 72.40,
    :Illinois => 78.04,
    :Arizona => 73.42,
    :Michigan => 74.75
)

# decide the flow of each arc
@variable(ff, flow[arcs] >= 0)

# must meet the demand exactly for every node, aka inflow - outflow = capacity
@constraint(ff, demand_met[t in interior_nodes], sum(flow[(i,j)] for (i,j) in arcs if j == t) -
        sum(flow[(i,j)] for (i,j) in arcs if i == t) == interior_demands[t])

# for this case, finding the victors is the same as maximizing the flow out of each team node * associated ft percentage
@objective(ff, Max, sum(sum(flow[(i,j)] for (i,j) in arcs if i == t) * ftp[t] for t in team_nodes))

# solve the model
optimize!(ff)

# print the wins per team
for (i,j) in arcs
    println(value(flow[(i,j)]))
end
# Out:
# Running HiGHS 1.12.0 (git hash: 755a8e027): Copyright (c) 2025 HiGHS under MIT licence terms
# LP has 3 rows; 6 cols; 8 nonzeros
# Coefficient ranges:
#   Matrix  [1e+00, 1e+00]
#   Cost    [7e+01, 8e+01]
#   Bound   [0e+00, 0e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 2 rows, 5 cols, 6 nonzeros  0s
# 0 rows, 0 cols, 0 nonzeros  0s
# Presolve reductions: rows 0(-3); columns 0(-6); nonzeros 0(-8) - Reduced to empty
# Performed postsolve
# Solving the original LP from the solution after postsolve
#
# Model status        : Optimal
# Objective value     :  2.3083000000e+02
# P-D objective error :  6.1431092877e-17
# HiGHS run time      :          0.00
# 0.0
# 2.0
# 1.0
# 0.0
# 1.0
# 0.0

# %% [markdown]
# ## 4. Discussion of Results ##
#
# Here, you display and discuss the results. Show figures, tables, plots, images, trade-off curves, or whatever else you can think of to best illustrate your results. The discussion should explain what the results mean, and how to interpret them. You should also explain the limitations of your approach/model and how sensitive your results are to the assumptions you made.
#
#  Use plots (see `Plots` examples from class), or you can display results in a table like this:
#
# | Tables        | Are          | Cool  |
# | ------------- |:-------------| -----:|
# | col 3 is      |right-aligned |\$1600 |
# |  colons       | align columns|  \$12 |
# | zebra stripes |    are neat  |   \$1 |
#
# ### 4.A. Feel free to add subsections
#
# #### 4.A.a. or subsubsections

# %% [markdown]
# ## 5. Conclusion ##
#
# Summarize your findings and your results, and talk about at least one possible future direction; something that might be interesting to pursue as a follow-up to your project.
